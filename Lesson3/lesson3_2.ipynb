# %%
print("Hello Python")
# Out:
# Hello Python

# %%
m1 = 5
m2 = 5.0
m3 = "5.0"

print(type(m1))
print(type(m2))
print(type(m3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
apple = 5
orange = 10
print(f"蘋果有{apple}個,橘子有{orange}個")
# Out:
# 蘋果有5個,橘子有10個

# %%
chinese = 55
chinese = chinese + 7
print(chinese)
# Out:
# 62

# %%
english = 10
english += 15
english *= 4
print(english)
# Out:
# 100
