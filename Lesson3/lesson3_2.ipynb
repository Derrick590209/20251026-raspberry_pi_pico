# %%
print("Hello Python")
# Out:
# Hello Python

# %%
10-5
# Out:
# 5

# %%
m1 = 5
m2 = 5.0
m3 = "5.0"

print(type(m1))
print(type(m2))
print(type(m3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
