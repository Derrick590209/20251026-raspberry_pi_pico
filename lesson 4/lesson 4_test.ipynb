# %%
apple = 5
orange = 3
apple + orange
# Out:
# 8

# %%
import random
value = 10

random_value = random.randint(1,10)
value += random_value
print(value)
# Out:
# 16

# %%
type(int( input("好嗎:")))
# Out:
# int
